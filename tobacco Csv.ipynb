# %%
import pandas as pd

csv = "Data/Behavioral_Risk_2011_clean.csv"

tobacco_df = pd.read_csv(csv)
tobacco_df.head()
# Out:
#    YEAR LocationAbbr          LocationDesc                  TopicType  \
# 0  2018           KY              Kentucky  Tobacco Use – Survey Data
# 1  2018           CO              Colorado  Tobacco Use – Survey Data
# 2  2018           DC  District of Columbia  Tobacco Use – Survey Data
# 3  2018           WI             Wisconsin  Tobacco Use – Survey Data
# 4  2018           GA               Georgia  Tobacco Use – Survey Data
#
#                 TopicDesc     MeasureDesc DataSource Response Data_Value_Unit  \
# 0  Cigarette Use (Adults)  Smoking Status      BRFSS  Current               %
# 1  Cigarette Use (Adults)  Smoking Status      BRFSS  Current               %
# 2  Cigarette Use (Adults)  Smoking Status      BRFSS  Current               %
# 3  Cigarette Use (Adults)  Smoking Status      BRFSS  Current               %
# 4  Cigarette Use (Adults)  Smoking Status      BRFSS  Current               %
#
#   Data_Value_Type  ...  Data_Value_Footnote  Data_Value_Std_Err  \
# ...

# %%
df_start = tobacco_df.filter(['YEAR', 'TopicDesc', 'MeasureDesc', 'Response', 'Data_Value', 'Sample_Size', 'Gender'])
df_start['Data_Value'].astype(float)
df_start['Sample_Size'].astype(float)
df_start['Reponse Number'] = gender_start.Data_Value * (gender_start.Sample_Size / 100)
df_start
# Out:
#        YEAR                       TopicDesc     MeasureDesc     Response  \
# 0      2018          Cigarette Use (Adults)  Smoking Status      Current
# 1      2018          Cigarette Use (Adults)  Smoking Status      Current
# 2      2018          Cigarette Use (Adults)  Smoking Status      Current
# 3      2018          Cigarette Use (Adults)  Smoking Status      Current
# 4      2018          Cigarette Use (Adults)  Smoking Status      Current
# ...     ...                             ...             ...          ...
# 33321  2011  Smokeless Tobacco Use (Adults)  Smoking Status  Not Current
# 33322  2011  Smokeless Tobacco Use (Adults)  Smoking Status  Not Current
# 33323  2011  Smokeless Tobacco Use (Adults)  Smoking Status  Not Current
# 33324  2011  Smokeless Tobacco Use (Adults)  Smoking Status  Not Current
# 33325  2011  Smokeless Tobacco Use (Adults)  Smoking Status  Not Current
#
#        Data_Value  Sample_Size   Gender  Reponse Number
# ...

# %%
gender_start = df_start
gender_start = gender_start[gender_start.MeasureDesc !="Frequency of Use"]
gender_start = gender_start[gender_start.Gender !="Overall"]
gender_start = gender_start[gender_start.Response !="Not Current"]
gender_start = gender_start[gender_start.Response !="Former"]
gender_start = gender_start[gender_start.Response !="Never"]
gender_group = gender_start.groupby(['YEAR', 'Response', 'Gender']).agg({'Data_Value': ['mean']})
gender_group
# Out:
#                      Data_Value
#                            mean
# YEAR Response Gender
# 2011 Current  Female  10.638679
#               Male    15.816038
# 2012 Current  Female   9.923585
#               Male    14.816038
# 2013 Current  Female   9.627673
#               Male    14.725472
# 2014 Current  Female   9.317296
#               Male    14.013208
# 2015 Current  Female   8.853459
#               Male    13.865094
# 2016 Current  Female   7.123061
#               Male    10.938994
# 2017 Current  Female   7.137526
#               Male    10.871698
# 2018 Current  Female   7.554916
#               Male    11.510072

# %%
type_df = df_start
type_df = type_df.groupby(['YEAR', 'TopicDesc', 'Response', 'Gender']).agg({'Data_Value': ['mean']})

type_df
# Out:
#                                                         Data_Value
#                                                               mean
# YEAR TopicDesc                      Response    Gender
# 2011 Cigarette Use (Adults)         Current     Female   20.200629
#                                                 Male     23.743396
#                                                 Overall  22.958576
#                                     Every Day   Female   73.562264
#                                                 Male     71.435849
# ...                                                            ...
# 2018 Smokeless Tobacco Use (Adults) Not Current Male     92.447170
#                                                 Overall  95.709259
#                                     Some Days   Female   60.600000
#                                                 Male     44.164000
#                                                 Overall  47.190385
#
# [261 rows x 1 columns]

# %%
freq_start = df_start

freq_start = freq_start[freq_start.MeasureDesc !="Smoking Status"]
freq_start = freq_start[freq_start.MeasureDesc !="Percent of Former Smokers Among Ever Smokers"]
freq_start = freq_start[freq_start.MeasureDesc !="Quit Attempt in Past Year Among Every Day Cigarette Smokers"]

freq_start = freq_start.groupby(['YEAR', 'TopicDesc', 'MeasureDesc', 'Response']).agg({'Data_Value': ['mean']})
freq_start
# Out:
#                                                                Data_Value
#                                                                      mean
# YEAR TopicDesc                      MeasureDesc      Response
# 2011 Cigarette Use (Adults)         Frequency of Use Every Day  72.473585
#                                                      Some Days  27.526415
#      Smokeless Tobacco Use (Adults) Frequency of Use Every Day  49.108000
#                                                      Some Days  50.892000
# 2012 Cigarette Use (Adults)         Frequency of Use Every Day  71.274214
#                                                      Some Days  28.725786
#      Smokeless Tobacco Use (Adults) Frequency of Use Every Day  50.984211
#                                                      Some Days  49.015789
# 2013 Cigarette Use (Adults)         Frequency of Use Every Day  71.208805
#                                                      Some Days  28.791195
# ...
